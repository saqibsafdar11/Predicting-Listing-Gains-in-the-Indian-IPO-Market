# %% [markdown]
# ### Loading the Libraries and the Data

# %% [markdown]
# An investment firm is interested in investing in the Initial Public Offerings (IPO) in the Indian market. We are going to build a deep learning classification model to determine if there will be listing gains for the IPO. Listing gains are the percentage increase in the share price of a company from its IPO issue price on the day of listing.
#
# The dataset we'll be using for this project contains information on past IPOs in the Indian market and comes from moneycontrol.

# %% [markdown]
# Data Dictionary
# The data consists of following columns:
#
# Date: date when the IPO was listed
#
# IPOName: name of the IPO
#
# Issue_Size: size of the IPO issue, in INR Crores
#
# Subscription_QIB: number of times the IPO was subscribed by the QIB (Qualified Institutional Buyer) investor category
#
# Subscription_HNI: number of times the IPO was subscribed by the HNI (High Networth Individual) investor category
#
# Subscription_RII: number of times the IPO was subscribed by the RII (Retail Individual Investors) investor category
#
# Subscription_Total: total number of times the IPO was subscribed overall
#
# Issue_Price: the price in INR at which the IPO was issued
#
# Listing_Gains_Percent: is the percentage gain in the listing price over the issue price

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From c:\Users\saqib\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv('Indian_IPO_Market_Data.csv')
print(df.shape)
df.head()
# Out:
# (319, 9)
#       Date           IPOName  Issue_Size  Subscription_QIB  Subscription_HNI  \
# 0  03/02/10    Infinite Comp      189.80             48.44            106.02
# 1  08/02/10    Jubilant Food      328.70             59.39             51.95
# 2  15/02/10    Syncom Health       56.25              0.99             16.60
# 3  15/02/10  Vascon Engineer      199.80              1.12              3.65
# 4  19/02/10      Thangamayil        0.00              0.52              1.52
#
#    Subscription_RII  Subscription_Total  Issue_Price  Listing_Gains_Percent
# 0             11.08               43.22          165                  11.82
# 1              3.79               31.11          145                 -84.21
# 2              6.25                5.17           75                  17.13
# 3              0.62                1.22          165                 -11.28
# 4              2.26                1.12           75                  -5.20

# %% [markdown]
# Data set has 319 rows and 9 columns

# %%
#informatio about columns in the data set
df.info()

# no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   319 non-null    object
#  1   IPOName                319 non-null    object
#  2   Issue_Size             319 non-null    float64
#  3   Subscription_QIB       319 non-null    float64
#  4   Subscription_HNI       319 non-null    float64
#  5   Subscription_RII       319 non-null    float64
#  6   Subscription_Total     319 non-null    float64
#  7   Issue_Price            319 non-null    int64
#  8   Listing_Gains_Percent  319 non-null    float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 22.6+ KB

# %% [markdown]
# The `Listing_Gains_Percent` variable is the variable that will be used to create the target or outcome variable

# %%
# summary statistics for the Listing_Gains_Percent column

df['Listing_Gains_Percent'].describe()
# Out:
# count    319.000000
# mean       4.742696
# std       47.650946
# min      -97.150000
# 25%      -11.555000
# 50%        1.810000
# 75%       25.310000
# max      270.400000
# Name: Listing_Gains_Percent, dtype: float64

# %%
#summary statistics for all variables of the dataset

df.describe(include='all')
# Out:
#            Date         IPOName    Issue_Size  Subscription_QIB  \
# count        319            319    319.000000        319.000000
# unique       287            319           NaN               NaN
# top     16/08/21  Infinite Comp           NaN               NaN
# freq           4              1           NaN               NaN
# mean         NaN            NaN   1192.859969         25.684138
# std          NaN            NaN   2384.643786         40.716782
# min          NaN            NaN      0.000000          0.000000
# 25%          NaN            NaN    169.005000          1.150000
# 50%          NaN            NaN    496.250000          4.940000
# 75%          NaN            NaN   1100.000000         34.635000
# max          NaN            NaN  21000.000000        215.450000
#
#         Subscription_HNI  Subscription_RII  Subscription_Total  Issue_Price  \
# count         319.000000        319.000000          319.000000   319.000000
# unique               NaN               NaN                 NaN          NaN
# top                  NaN               NaN                 NaN          NaN
# freq                 NaN               NaN                 NaN          NaN
# mean           70.091379          8.561599           27.447147   375.128527
# std           142.454416         14.508670           48.772203   353.897614
# min             0.000000          0.000000            0.000000     0.000000
# 25%             1.255000          1.275000            1.645000   119.000000
# 50%             5.070000          3.420000            4.930000   250.000000
# 75%            62.095000          8.605000           33.395000   536.000000
# max           958.070000        119.440000          326.490000  2150.000000
#
#         Listing_Gains_Percent
# count              319.000000
# unique                    NaN
# top                       NaN
# freq                      NaN
# mean                 4.742696
# std                 47.650946
# min                -97.150000
# 25%                -11.555000
# 50%                  1.810000
# 75%                 25.310000
# max                270.400000

# %% [markdown]
# ## Exploring the Data

# %%
#Listing_Gains_Percent target variable is continous. We will need to convert it into a categorical variable before we can proceed.

df['Listing_Gains_Profit'] = np.where(df['Listing_Gains_Percent'] > 0, 1, 0)

df['Listing_Gains_Profit'].describe()
# Out:
# count    319.000000
# mean       0.545455
# std        0.498712
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Listing_Gains_Profit, dtype: float64

# %%
df.isnull().sum() # no missing values
# Out:
# Date                     0
# IPOName                  0
# Issue_Size               0
# Subscription_QIB         0
# Subscription_HNI         0
# Subscription_RII         0
# Subscription_Total       0
# Issue_Price              0
# Listing_Gains_Percent    0
# Listing_Gains_Profit     0
# dtype: int64

# %%
df['Listing_Gains_Profit'].value_counts(normalize=True)
# Out:
# 1    0.545455
# 0    0.454545
# Name: Listing_Gains_Profit, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   319 non-null    object
#  1   IPOName                319 non-null    object
#  2   Issue_Size             319 non-null    float64
#  3   Subscription_QIB       319 non-null    float64
#  4   Subscription_HNI       319 non-null    float64
#  5   Subscription_RII       319 non-null    float64
#  6   Subscription_Total     319 non-null    float64
#  7   Issue_Price            319 non-null    int64
#  8   Listing_Gains_Percent  319 non-null    float64
#  9   Listing_Gains_Profit   319 non-null    int32
# dtypes: float64(6), int32(1), int64(1), object(2)
# memory usage: 23.8+ KB

# %%
#percentage of profitable IPOs
profitable_ipos = df[df['Listing_Gains_Profit'] > 0]
percentage_profitable = (len(profitable_ipos) / len(df)) * 100
percentage_profitable
# Out:
# 54.54545454545454

# %%
#drop columns that are not needed
df = df.drop(['Date ', 'IPOName', 'Listing_Gains_Percent'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Issue_Size            319 non-null    float64
#  1   Subscription_QIB      319 non-null    float64
#  2   Subscription_HNI      319 non-null    float64
#  3   Subscription_RII      319 non-null    float64
#  4   Subscription_Total    319 non-null    float64
#  5   Issue_Price           319 non-null    int64
#  6   Listing_Gains_Profit  319 non-null    int32
# dtypes: float64(5), int32(1), int64(1)
# memory usage: 16.3 KB

# %% [markdown]
# Approximately 55% of the IPOs listed in profit, and the data is fairly balanced. We have also dropped some of the variables that might not carry predictive power

# %% [markdown]
# ## Data Visualisation
#
# We want to check for the distribution of predictors with respect to the target variable, since they could be informative for modeling

# %%
#Countplot to visualize the distribution of the target variable

sns.countplot(data=df, x='Listing_Gains_Profit')

# Set title
plt.title('Distribution of Listing Gains Profit')

# Show the plot
plt.show()

# %%
#check for presence of outliers
plt.figure(figsize=(20, 10))
sns.boxplot(data=df, orient='h')
# Out:
# <Axes: >

# %%
plt.figure(figsize=[8,5])
sns.histplot(data=df, x='Issue_Size', bins=50).set(title='Distribution of Issue_Size', ylabel='Count')
plt.show()

# %%
plt.figure(figsize=[8,5])
sns.histplot(data=df, x='Issue_Price', bins=50).set(title='Distribution of Issue_Price', ylabel='Count')
plt.show()

# %%
sns.boxplot(data=df, x='Listing_Gains_Profit', y='Issue_Price')
plt.title('Boxplot of Issue_Price with respect to Listing Gains Type')
plt.xlabel('Listing Profit (No=0, Yes=1)')
plt.show()

# %%
print(df.skew())
# Out:
# Issue_Size              4.853402
# Subscription_QIB        2.143705
# Subscription_HNI        3.078445
# Subscription_RII        3.708274
# Subscription_Total      2.911907
# Issue_Price             1.696881
# Listing_Gains_Profit   -0.183438
# dtype: float64

# %%
sns.scatterplot(data=df, x='Subscription_RII', y='Subscription_Total')
plt.title('Scatterplot between Retail and Total IPO Subscription')
plt.show()

# %%
sns.pairplot(df) #pairplot to visualize the relationship between variables

# %% [markdown]
# Findings:
#
# 1. The histogram and the boxplots show that outliers are present in the data and might need outlier treatment.
#
# 2. The boxplot of `Issue_Price`, with respect to `Listing_Gains_Profit`, shows that there are more outliers for IPOs that listed a loss than there are outliers for IPOs that listed a profit.
#
# 3. We also observed a correlation between Retail and Total IPO Subscription via a scatterplot.

# %% [markdown]
# We will now treat the outliers using interquartile method by clipping the values at the upper and lower bounds

# %%
q1 = df['Issue_Size'].quantile(q=0.25)
q3 = df['Issue_Size'].quantile(q=0.75)  
iqr = q3 - q1   
lower = (q1 - 1.5 * iqr) 
upper = (q3 + 1.5 * iqr) 
print('IQR = ', iqr, '\nlower = ', lower, '\nupper = ', upper, sep='')
# Out:
# IQR = 930.995
# lower = -1227.4875000000002
# upper = 2496.4925000000003

# %%
df['Issue_Size'] = df['Issue_Size'].clip(lower, upper)
df['Issue_Size'].describe()
# Out:
# count     319.000000
# mean      763.561238
# std       769.689122
# min         0.000000
# 25%       169.005000
# 50%       496.250000
# 75%      1100.000000
# max      2496.492500
# Name: Issue_Size, dtype: float64

# %%
q1 = df['Subscription_QIB'].quantile(q=0.25)
q3 = df['Subscription_QIB'].quantile(q=0.75)  
iqr = q3 - q1   
lower = (q1 - 1.5 * iqr) 
upper = (q3 + 1.5 * iqr) 
print('IQR = ', iqr, '\nlower = ', lower, '\nupper = ', upper, sep='')
# Out:
# IQR = 33.48500000000001
# lower = -49.07750000000001
# upper = 84.86250000000001

# %%
df['Subscription_QIB'] = df['Subscription_QIB'].clip(lower, upper)
df['Subscription_QIB'].describe()
# Out:
# count    319.000000
# mean      21.521183
# std       29.104549
# min        0.000000
# 25%        1.150000
# 50%        4.940000
# 75%       34.635000
# max       84.862500
# Name: Subscription_QIB, dtype: float64

# %%
q1 = df['Subscription_HNI'].quantile(q=0.25)
q3 = df['Subscription_HNI'].quantile(q=0.75)  
iqr = q3 - q1   
lower = (q1 - 1.5 * iqr) 
upper = (q3 + 1.5 * iqr) 
print('IQR = ', iqr, '\nlower = ', lower, '\nupper = ', upper, sep='')
# Out:
# IQR = 60.839999999999996
# lower = -90.005
# upper = 153.355

# %%
df['Subscription_HNI'] = df['Subscription_HNI'].clip(lower, upper)
df['Subscription_HNI'].describe()
# Out:
# count    319.000000
# mean      40.356426
# std       57.427921
# min        0.000000
# 25%        1.255000
# 50%        5.070000
# 75%       62.095000
# max      153.355000
# Name: Subscription_HNI, dtype: float64

# %%
q1 = df['Subscription_RII'].quantile(q=0.25)
q3 = df['Subscription_RII'].quantile(q=0.75)  
iqr = q3 - q1   
lower = (q1 - 1.5 * iqr) 
upper = (q3 + 1.5 * iqr) 
print('IQR = ', iqr, '\nlower = ', lower, '\nupper = ', upper, sep='')
# Out:
# IQR = 7.33
# lower = -9.72
# upper = 19.6

# %%
df['Subscription_RII'] = df['Subscription_RII'].clip(lower, upper)
df['Subscription_RII'].describe()
# Out:
# count    319.000000
# mean       6.060940
# std        6.176882
# min        0.000000
# 25%        1.275000
# 50%        3.420000
# 75%        8.605000
# max       19.600000
# Name: Subscription_RII, dtype: float64

# %%
q1 = df['Subscription_Total'].quantile(q=0.25)
q3 = df['Subscription_Total'].quantile(q=0.75)  
iqr = q3 - q1   
lower = (q1 - 1.5 * iqr) 
upper = (q3 + 1.5 * iqr) 
print('IQR = ', iqr, '\nlower = ', lower, '\nupper = ', upper, sep='')
# Out:
# IQR = 31.749999999999996
# lower = -45.97999999999999
# upper = 81.01999999999998

# %%
df['Subscription_Total'] = df['Subscription_Total'].clip(lower, upper)
df['Subscription_Total'].describe()
# Out:
# count    319.000000
# mean      20.456646
# std       27.217740
# min        0.000000
# 25%        1.645000
# 50%        4.930000
# 75%       33.395000
# max       81.020000
# Name: Subscription_Total, dtype: float64

# %%
q1 = df['Listing_Gains_Profit'].quantile(q=0.25)
q3 = df['Listing_Gains_Profit'].quantile(q=0.75)  
iqr = q3 - q1   
lower = (q1 - 1.5 * iqr) 
upper = (q3 + 1.5 * iqr) 
print('IQR = ', iqr, '\nlower = ', lower, '\nupper = ', upper, sep='')
# Out:
# IQR = 1.0
# lower = -1.5
# upper = 2.5

# %%
df['Listing_Gains_Profit'] = df['Listing_Gains_Profit'].clip(lower, upper)
df['Listing_Gains_Profit'].describe()
# Out:
# count    319.000000
# mean       0.545455
# std        0.498712
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Listing_Gains_Profit, dtype: float64

# %%
print(df.skew())
# Out:
# Issue_Size              1.224620
# Subscription_QIB        1.262734
# Subscription_HNI        1.181636
# Subscription_RII        1.129171
# Subscription_Total      1.293880
# Issue_Price             1.696881
# Listing_Gains_Profit   -0.183438
# dtype: float64

# %% [markdown]
# ## Setting the Target and Predictor Variables

# %%
target_variable = ['Listing_Gains_Profit'] 
predictors = list(set(list(df.columns)) - set(target_variable))
df[predictors] = df[predictors]/df[predictors].max()
df.describe()
# Out:
#        Issue_Size  Subscription_QIB  Subscription_HNI  Subscription_RII  \
# count  319.000000        319.000000        319.000000        319.000000
# mean     0.305854          0.253601          0.263157          0.309232
# std      0.308308          0.342961          0.374477          0.315147
# min      0.000000          0.000000          0.000000          0.000000
# 25%      0.067697          0.013551          0.008184          0.065051
# 50%      0.198779          0.058212          0.033061          0.174490
# 75%      0.440618          0.408131          0.404910          0.439031
# max      1.000000          1.000000          1.000000          1.000000
#
#        Subscription_Total  Issue_Price  Listing_Gains_Profit
# count          319.000000   319.000000            319.000000
# mean             0.252489     0.174478              0.545455
# std              0.335939     0.164604              0.498712
# min              0.000000     0.000000              0.000000
# 25%              0.020304     0.055349              0.000000
# 50%              0.060849     0.116279              1.000000
# 75%              0.412182     0.249302              1.000000
# max              1.000000     1.000000              1.000000

# %% [markdown]
# - We have created an array of the target variable Listing_Gains_Profit
# - We have crated an array of predictor variables (all excluding the target variable)
# - We have performed normalisation to by scaling the predictors as this could affect the modelling process.

# %% [markdown]
# ## Creating the Holdout Validation Approach

# %%
X = df[predictors].values
y = df[target_variable].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=100)
print(X_train.shape); print(X_test.shape)
# Out:
# (223, 6)
# (96, 6)

# %% [markdown]
# We will use the hold out validation approach to model evaluation. In this approach, we will divide the data in the 70:30 ratio, where we will use 70% of the data for training the model, while we will use the other 30% of the data to test the model

# %% [markdown]
# ## Define the Deep Learning Classification Model

# %% [markdown]
# Now lets build the model. We will carry out the following steps
#
# 1. Instantiating the model
# 2. Adding the hidden layers
# 3. Selecting the activation functions

# %%
#Instantiate a model with the Keras Sequential API in TensorFlow.
tf.random.set_seed(100) #set seed for reproducibility
model = keras.Sequential() 

#Add layers to the model
model.add(tf.keras.layers.Dense(32, input_shape = (X_train.shape[1],), activation = 'relu'))
model.add(tf.keras.layers.Dense(16, activation= 'relu'))
model.add(tf.keras.layers.Dense(8, activation= 'relu'))
model.add(tf.keras.layers.Dense(4, activation= 'relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From c:\Users\saqib\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# The model architecture is comprised of four hidden layers with `relu` as the activation function. The output layer uses a `sigmoid` activation function, which is a good choice for a binary classification model.

# %% [markdown]
# ## Compile and Train the model

# %% [markdown]
# We will now compile and train the model using the following steps:
#
# 1. An optimizer
# 2. A loss function
# 3. An evaluation metric

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(0.001), #Adam optimizer with learning rate of 0.001
              loss=tf.keras.losses.BinaryCrossentropy(), #Binary Crossentropy loss function
              metrics=['accuracy']) #accuracy metric

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                224
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 4)                 36
#
#  dense_4 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 929 (3.63 KB)
# Trainable params: 929 (3.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=250)
# Out:
# Epoch 1/250
# WARNING:tensorflow:From c:\Users\saqib\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\saqib\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 7/7 [==============================] - 2s 4ms/step - loss: 0.7052 - accuracy: 0.4395
# Epoch 2/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6983 - accuracy: 0.4126
# Epoch 3/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6948 - accuracy: 0.4439
# Epoch 4/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6920 - accuracy: 0.5516
# Epoch 5/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6908 - accuracy: 0.5471
# Epoch 6/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6894 - accuracy: 0.5561
# Epoch 7/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6878 - accuracy: 0.5605
# Epoch 8/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6859 - accuracy: 0.5650
# Epoch 9/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6837 - accuracy: 0.5650
# Epoch 10/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6810 - accuracy: 0.5650
# Epoch 11/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6782 - accuracy: 0.5650
# Epoch 12/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6748 - accuracy: 0.5605
# Epoch 13/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6705 - accuracy: 0.5605
# Epoch 14/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6667 - accuracy: 0.5561
# Epoch 15/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6623 - accuracy: 0.5561
# Epoch 16/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6578 - accuracy: 0.5605
# Epoch 17/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6525 - accuracy: 0.5605
# Epoch 18/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6493 - accuracy: 0.5605
# Epoch 19/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6446 - accuracy: 0.5605
# Epoch 20/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6415 - accuracy: 0.5650
# Epoch 21/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6372 - accuracy: 0.5605
# Epoch 22/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6337 - accuracy: 0.5830
# Epoch 23/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6305 - accuracy: 0.6413
# Epoch 24/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6281 - accuracy: 0.6502
# Epoch 25/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6255 - accuracy: 0.6547
# Epoch 26/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6245 - accuracy: 0.6592
# Epoch 27/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6232 - accuracy: 0.6592
# Epoch 28/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6211 - accuracy: 0.6502
# Epoch 29/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6200 - accuracy: 0.6502
# Epoch 30/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6192 - accuracy: 0.6547
# Epoch 31/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6184 - accuracy: 0.6547
# Epoch 32/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6178 - accuracy: 0.6682
# Epoch 33/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6170 - accuracy: 0.6592
# Epoch 34/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6160 - accuracy: 0.6592
# Epoch 35/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6156 - accuracy: 0.6547
# Epoch 36/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6154 - accuracy: 0.6637
# Epoch 37/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6151 - accuracy: 0.6637
# Epoch 38/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6141 - accuracy: 0.6682
# Epoch 39/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6140 - accuracy: 0.6637
# Epoch 40/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6137 - accuracy: 0.6637
# Epoch 41/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6131 - accuracy: 0.6637
# Epoch 42/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6130 - accuracy: 0.6637
# Epoch 43/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6125 - accuracy: 0.6682
# Epoch 44/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6129 - accuracy: 0.6682
# Epoch 45/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6124 - accuracy: 0.6682
# Epoch 46/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6125 - accuracy: 0.6682
# Epoch 47/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6115 - accuracy: 0.6682
# Epoch 48/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6110 - accuracy: 0.6726
# Epoch 49/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6105 - accuracy: 0.6592
# Epoch 50/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6102 - accuracy: 0.6682
# Epoch 51/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6106 - accuracy: 0.6682
# Epoch 52/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6104 - accuracy: 0.6726
# Epoch 53/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6097 - accuracy: 0.6726
# Epoch 54/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6092 - accuracy: 0.6682
# Epoch 55/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6087 - accuracy: 0.6682
# Epoch 56/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6087 - accuracy: 0.6682
# Epoch 57/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6089 - accuracy: 0.6682
# Epoch 58/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6082 - accuracy: 0.6682
# Epoch 59/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6075 - accuracy: 0.6682
# Epoch 60/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6078 - accuracy: 0.6726
# Epoch 61/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6069 - accuracy: 0.6726
# Epoch 62/250
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6067 - accuracy: 0.6726
# Epoch 63/250
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6069 - accuracy: 0.6726
# Epoch 64/250
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6068 - accuracy: 0.6726
# Epoch 65/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6059 - accuracy: 0.6726
# Epoch 66/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6055 - accuracy: 0.6726
# Epoch 67/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6056 - accuracy: 0.6682
# Epoch 68/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6050 - accuracy: 0.6682
# Epoch 69/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6048 - accuracy: 0.6726
# Epoch 70/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6041 - accuracy: 0.6816
# Epoch 71/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6038 - accuracy: 0.6726
# Epoch 72/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6044 - accuracy: 0.6637
# Epoch 73/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6042 - accuracy: 0.6682
# Epoch 74/250
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6038 - accuracy: 0.6726
# Epoch 75/250
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6024 - accuracy: 0.6771
# Epoch 76/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6020 - accuracy: 0.6771
# Epoch 77/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6014 - accuracy: 0.6771
# Epoch 78/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6008 - accuracy: 0.6726
# Epoch 79/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6009 - accuracy: 0.6726
# Epoch 80/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6000 - accuracy: 0.6682
# Epoch 81/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5992 - accuracy: 0.6816
# Epoch 82/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5990 - accuracy: 0.6816
# Epoch 83/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5986 - accuracy: 0.6771
# Epoch 84/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5981 - accuracy: 0.6726
# Epoch 85/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5973 - accuracy: 0.6726
# Epoch 86/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5970 - accuracy: 0.6726
# Epoch 87/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5961 - accuracy: 0.6816
# Epoch 88/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5958 - accuracy: 0.6816
# Epoch 89/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5957 - accuracy: 0.6816
# Epoch 90/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5951 - accuracy: 0.6816
# Epoch 91/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5945 - accuracy: 0.6771
# Epoch 92/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5942 - accuracy: 0.6726
# Epoch 93/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5933 - accuracy: 0.6726
# Epoch 94/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5936 - accuracy: 0.6816
# Epoch 95/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5923 - accuracy: 0.6816
# Epoch 96/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5920 - accuracy: 0.6771
# Epoch 97/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5907 - accuracy: 0.6726
# Epoch 98/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5906 - accuracy: 0.6771
# Epoch 99/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5900 - accuracy: 0.6906
# Epoch 100/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5894 - accuracy: 0.6906
# Epoch 101/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5887 - accuracy: 0.6816
# Epoch 102/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5884 - accuracy: 0.6816
# Epoch 103/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5875 - accuracy: 0.6816
# Epoch 104/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5866 - accuracy: 0.6906
# Epoch 105/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5868 - accuracy: 0.6906
# Epoch 106/250
# 7/7 [==============================] - 0s 14ms/step - loss: 0.5861 - accuracy: 0.6861
# Epoch 107/250
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5842 - accuracy: 0.6816
# Epoch 108/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5847 - accuracy: 0.6816
# Epoch 109/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5836 - accuracy: 0.6906
# Epoch 110/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5818 - accuracy: 0.6861
# Epoch 111/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5822 - accuracy: 0.6816
# Epoch 112/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5814 - accuracy: 0.6951
# Epoch 113/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5798 - accuracy: 0.6816
# Epoch 114/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5780 - accuracy: 0.6861
# Epoch 115/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5772 - accuracy: 0.6816
# Epoch 116/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5766 - accuracy: 0.6861
# Epoch 117/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5757 - accuracy: 0.6906
# Epoch 118/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5747 - accuracy: 0.6906
# Epoch 119/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5746 - accuracy: 0.6906
# Epoch 120/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5751 - accuracy: 0.6906
# Epoch 121/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5735 - accuracy: 0.6906
# Epoch 122/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5721 - accuracy: 0.6906
# Epoch 123/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5720 - accuracy: 0.6906
# Epoch 124/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5728 - accuracy: 0.6996
# Epoch 125/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5696 - accuracy: 0.6906
# Epoch 126/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5703 - accuracy: 0.6816
# Epoch 127/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5689 - accuracy: 0.6816
# Epoch 128/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5713 - accuracy: 0.7085
# Epoch 129/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5707 - accuracy: 0.6951
# Epoch 130/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5726 - accuracy: 0.6771
# Epoch 131/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5692 - accuracy: 0.6861
# Epoch 132/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5684 - accuracy: 0.7130
# Epoch 133/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5669 - accuracy: 0.6861
# Epoch 134/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5657 - accuracy: 0.6861
# Epoch 135/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5647 - accuracy: 0.6951
# Epoch 136/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5643 - accuracy: 0.6996
# Epoch 137/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5643 - accuracy: 0.6996
# Epoch 138/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5641 - accuracy: 0.6996
# Epoch 139/250
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5642 - accuracy: 0.6906
# Epoch 140/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5629 - accuracy: 0.6951
# Epoch 141/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5612 - accuracy: 0.7040
# Epoch 142/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5617 - accuracy: 0.6996
# Epoch 143/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5601 - accuracy: 0.7040
# Epoch 144/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5597 - accuracy: 0.6996
# Epoch 145/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5594 - accuracy: 0.6906
# Epoch 146/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5606 - accuracy: 0.6996
# Epoch 147/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5591 - accuracy: 0.6951
# Epoch 148/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5586 - accuracy: 0.6996
# Epoch 149/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5571 - accuracy: 0.6951
# Epoch 150/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5579 - accuracy: 0.6951
# Epoch 151/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5565 - accuracy: 0.7040
# Epoch 152/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5559 - accuracy: 0.6996
# Epoch 153/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5550 - accuracy: 0.7040
# Epoch 154/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5546 - accuracy: 0.6996
# Epoch 155/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5564 - accuracy: 0.6996
# Epoch 156/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5540 - accuracy: 0.7040
# Epoch 157/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5532 - accuracy: 0.6906
# Epoch 158/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5534 - accuracy: 0.7040
# Epoch 159/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5517 - accuracy: 0.7040
# Epoch 160/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5534 - accuracy: 0.6996
# Epoch 161/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5527 - accuracy: 0.7040
# Epoch 162/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5540 - accuracy: 0.7130
# Epoch 163/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5513 - accuracy: 0.7085
# Epoch 164/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5514 - accuracy: 0.6951
# Epoch 165/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5501 - accuracy: 0.7040
# Epoch 166/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5492 - accuracy: 0.7040
# Epoch 167/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5500 - accuracy: 0.7040
# Epoch 168/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5493 - accuracy: 0.7040
# Epoch 169/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5484 - accuracy: 0.7040
# Epoch 170/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5551 - accuracy: 0.7040
# Epoch 171/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5482 - accuracy: 0.7085
# Epoch 172/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5500 - accuracy: 0.7085
# Epoch 173/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5470 - accuracy: 0.7085
# Epoch 174/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5465 - accuracy: 0.7040
# Epoch 175/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5463 - accuracy: 0.7040
# Epoch 176/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5503 - accuracy: 0.6906
# Epoch 177/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.7040
# Epoch 178/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5453 - accuracy: 0.6996
# Epoch 179/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5441 - accuracy: 0.7085
# Epoch 180/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5435 - accuracy: 0.7085
# Epoch 181/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5431 - accuracy: 0.7085
# Epoch 182/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5427 - accuracy: 0.7085
# Epoch 183/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5433 - accuracy: 0.7085
# Epoch 184/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5423 - accuracy: 0.7175
# Epoch 185/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5420 - accuracy: 0.7085
# Epoch 186/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5428 - accuracy: 0.7130
# Epoch 187/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5420 - accuracy: 0.7220
# Epoch 188/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5400 - accuracy: 0.7130
# Epoch 189/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5393 - accuracy: 0.7130
# Epoch 190/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5387 - accuracy: 0.7085
# Epoch 191/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5395 - accuracy: 0.7130
# Epoch 192/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5437 - accuracy: 0.7130
# Epoch 193/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5389 - accuracy: 0.7175
# Epoch 194/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5385 - accuracy: 0.7220
# Epoch 195/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5374 - accuracy: 0.7130
# Epoch 196/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5375 - accuracy: 0.7130
# Epoch 197/250
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5373 - accuracy: 0.7265
# Epoch 198/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5396 - accuracy: 0.7175
# Epoch 199/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5387 - accuracy: 0.7130
# Epoch 200/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5356 - accuracy: 0.7220
# Epoch 201/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5358 - accuracy: 0.7175
# Epoch 202/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5351 - accuracy: 0.7220
# Epoch 203/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5352 - accuracy: 0.7175
# Epoch 204/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5366 - accuracy: 0.7130
# Epoch 205/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5327 - accuracy: 0.7220
# Epoch 206/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5332 - accuracy: 0.7265
# Epoch 207/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5337 - accuracy: 0.7175
# Epoch 208/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5344 - accuracy: 0.7130
# Epoch 209/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5352 - accuracy: 0.7309
# Epoch 210/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5324 - accuracy: 0.7309
# Epoch 211/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5320 - accuracy: 0.7354
# Epoch 212/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5315 - accuracy: 0.7220
# Epoch 213/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5284 - accuracy: 0.7354
# Epoch 214/250
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5286 - accuracy: 0.7265
# Epoch 215/250
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5287 - accuracy: 0.7309
# Epoch 216/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5271 - accuracy: 0.7265
# Epoch 217/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5278 - accuracy: 0.7265
# Epoch 218/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5282 - accuracy: 0.7354
# Epoch 219/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5262 - accuracy: 0.7309
# Epoch 220/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5256 - accuracy: 0.7354
# Epoch 221/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5245 - accuracy: 0.7309
# Epoch 222/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5239 - accuracy: 0.7309
# Epoch 223/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5244 - accuracy: 0.7265
# Epoch 224/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5231 - accuracy: 0.7309
# Epoch 225/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5231 - accuracy: 0.7309
# Epoch 226/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5223 - accuracy: 0.7309
# Epoch 227/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5238 - accuracy: 0.7309
# Epoch 228/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5239 - accuracy: 0.7309
# Epoch 229/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5214 - accuracy: 0.7354
# Epoch 230/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5212 - accuracy: 0.7309
# Epoch 231/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5217 - accuracy: 0.7309
# Epoch 232/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5201 - accuracy: 0.7265
# Epoch 233/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5192 - accuracy: 0.7220
# Epoch 234/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5193 - accuracy: 0.7265
# Epoch 235/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5176 - accuracy: 0.7309
# Epoch 236/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5237 - accuracy: 0.7309
# Epoch 237/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5171 - accuracy: 0.7399
# Epoch 238/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5163 - accuracy: 0.7265
# Epoch 239/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5160 - accuracy: 0.7309
# Epoch 240/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5163 - accuracy: 0.7265
# Epoch 241/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5172 - accuracy: 0.7309
# Epoch 242/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5138 - accuracy: 0.7354
# Epoch 243/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5157 - accuracy: 0.7309
# Epoch 244/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5142 - accuracy: 0.7354
# Epoch 245/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5136 - accuracy: 0.7265
# Epoch 246/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5115 - accuracy: 0.7309
# Epoch 247/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5129 - accuracy: 0.7534
# Epoch 248/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5160 - accuracy: 0.7399
# Epoch 249/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5112 - accuracy: 0.7354
# Epoch 250/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5122 - accuracy: 0.7534

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# You have defined, compiled, and fit your deep learning classification model to the training data. The next step is to evaluate your model's performance.

# %%
#Evaluate the model on the train set
model.evaluate(X_train, y_train)
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5081 - accuracy: 0.7668
# [0.5081333518028259, 0.7668161392211914]

# %%
#Evaluate the model on the test set
model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6790 - accuracy: 0.6875
# [0.6789514422416687, 0.6875]

# %% [markdown]
# ## Conclusion
#
# The model evaluation output shows the performance of the model on both training and test data. The accuracy was approximately 75% on the training data and 69% on the test data. Ideally, the higher the accuracy value, the better the model is performing. It's noteworthy that the training and test set accuracies are a little off each other by 6%
